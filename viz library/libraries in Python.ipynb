# %%
pip install pandas
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("pull_files.csv")
data2 = pd.read_csv("pulls.csv")
data3 = pd.read_csv("pulls_2011.csv")
data4 = pd.read_csv("pulls_2014.csv")

# %%
data
# Out:
#              pid                                               file
# 0      163314316                    test/files/pos/t5638/Among.java
# 1      163314316                   test/files/pos/t5638/Usage.scala
# 2      163314316                         test/files/pos/t9291.scala
# 3      163314316                         test/files/run/t8348.check
# 4      163314316              test/files/run/t8348/TableColumn.java
# ...          ...                                                ...
# 85583     547354                       test/files/run/bitsets.check
# 85584     547354                       test/files/run/bitsets.scala
# 85585     547150  src/compiler/scala/tools/nsc/transform/LiftCod...
# 85586     547150          src/library/scala/reflect/api/Trees.scala
# 85587     547003                                         README.rst
#
# [85588 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85588 entries, 0 to 85587
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     85588 non-null  int64
#  1   file    85588 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ MB

# %%
data2
# Out:
#             pid       user                  date
# 0     163314316     hrhino  2018-01-16T23:29:16Z
# 1     163061502   joroKr21  2018-01-15T23:44:52Z
# 2     163057333  mkeskells  2018-01-15T23:05:06Z
# 3     162985594      lrytz  2018-01-15T15:52:39Z
# 4     162838837  zuvizudar  2018-01-14T19:16:16Z
# ...         ...        ...                   ...
# 6195     547941    xeno-by  2011-12-01T16:16:42Z
# 6196     547354    szeiger  2011-12-01T14:03:23Z
# 6197     547150    odersky  2011-12-01T12:39:40Z
# 6198     547003    robinst  2011-12-01T11:42:26Z
# 6199     546847    odersky  2011-12-01T10:41:01Z
#
# [6200 rows x 3 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6200 entries, 0 to 6199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     6200 non-null   int64
#  1   user    6200 non-null   object
#  2   date    6200 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 145.4+ KB

# %%
data3
# Out:
#            pid         user                  date
# 0     11166973  VladimirNik  2013-12-31T23:10:55Z
# 1     11161892      Ichoran  2013-12-31T16:55:47Z
# 2     11153894      Ichoran  2013-12-31T02:41:13Z
# 3     11151917      rklaehn  2013-12-30T23:45:47Z
# 4     11131244        qerub  2013-12-29T17:21:01Z
# ...        ...          ...                   ...
# 3291    547941      xeno-by  2011-12-01T16:16:42Z
# 3292    547354      szeiger  2011-12-01T14:03:23Z
# 3293    547150      odersky  2011-12-01T12:39:40Z
# 3294    547003      robinst  2011-12-01T11:42:26Z
# 3295    546847      odersky  2011-12-01T10:41:01Z
#
# [3296 rows x 3 columns]

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3296 entries, 0 to 3295
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     3296 non-null   int64
#  1   user    3296 non-null   object
#  2   date    3296 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 77.4+ KB

# %%
data4
# Out:
#             pid       user                  date
# 0     163314316     hrhino  2018-01-16T23:29:16Z
# 1     163061502   joroKr21  2018-01-15T23:44:52Z
# 2     163057333  mkeskells  2018-01-15T23:05:06Z
# 3     162985594      lrytz  2018-01-15T15:52:39Z
# 4     162838837  zuvizudar  2018-01-14T19:16:16Z
# ...         ...        ...                   ...
# 2899   11244241     folone  2014-01-06T09:07:34Z
# 2900   11240674   clhodapp  2014-01-06T03:52:23Z
# 2901   11234757    xeno-by  2014-01-05T12:23:24Z
# 2902   11231462    rklaehn  2014-01-04T22:42:02Z
# 2903   11188295    rklaehn  2014-01-02T18:55:33Z
#
# [2904 rows x 3 columns]

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2904 entries, 0 to 2903
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     2904 non-null   int64
#  1   user    2904 non-null   object
#  2   date    2904 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 68.2+ KB

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
data_pulls = data2.append(data3)

# %%
#datapulls = data_pulls.append(data4)

# %%
datapulls
# Out:
#             pid       user                  date
# 0     163314316     hrhino  2018-01-16T23:29:16Z
# 1     163061502   joroKr21  2018-01-15T23:44:52Z
# 2     163057333  mkeskells  2018-01-15T23:05:06Z
# 3     162985594      lrytz  2018-01-15T15:52:39Z
# 4     162838837  zuvizudar  2018-01-14T19:16:16Z
# ...         ...        ...                   ...
# 2899   11244241     folone  2014-01-06T09:07:34Z
# 2900   11240674   clhodapp  2014-01-06T03:52:23Z
# 2901   11234757    xeno-by  2014-01-05T12:23:24Z
# 2902   11231462    rklaehn  2014-01-04T22:42:02Z
# 2903   11188295    rklaehn  2014-01-02T18:55:33Z
#
# [12400 rows x 3 columns]

# %%
data_pulls['date'] = pd.to_datetime(data_pulls['date'], utc=True)

# %%
data_pulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9496 entries, 0 to 3295
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     9496 non-null   int64
#  1   user    9496 non-null   object
#  2   date    9496 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(1), object(1)
# memory usage: 296.8+ KB

# %%
mergedata =  data_pulls.merge(data, on='pid')

# %%
mergedata
# Out:
#               pid     user                      date  \
# 0       163314316   hrhino 2018-01-16 23:29:16+00:00
# 1       163314316   hrhino 2018-01-16 23:29:16+00:00
# 2       163314316   hrhino 2018-01-16 23:29:16+00:00
# 3       163314316   hrhino 2018-01-16 23:29:16+00:00
# 4       163314316   hrhino 2018-01-16 23:29:16+00:00
# ...           ...      ...                       ...
# 136985     547150  odersky 2011-12-01 12:39:40+00:00
# 136986     547150  odersky 2011-12-01 12:39:40+00:00
# 136987     547150  odersky 2011-12-01 12:39:40+00:00
# 136988     547003  robinst 2011-12-01 11:42:26+00:00
# 136989     547003  robinst 2011-12-01 11:42:26+00:00
#
#                                                      file
# 0                         test/files/pos/t5638/Among.java
# 1                        test/files/pos/t5638/Usage.scala
# 2                              test/files/pos/t9291.scala
# 3                              test/files/run/t8348.check
# ...

# %%
mergedata['month'] = mergedata['date'].dt.month

# %%
mergedata['year'] = mergedata['date'].dt.year

# %%
mergedata
# Out:
#               pid     user                      date  \
# 0       163314316   hrhino 2018-01-16 23:29:16+00:00
# 1       163314316   hrhino 2018-01-16 23:29:16+00:00
# 2       163314316   hrhino 2018-01-16 23:29:16+00:00
# 3       163314316   hrhino 2018-01-16 23:29:16+00:00
# 4       163314316   hrhino 2018-01-16 23:29:16+00:00
# ...           ...      ...                       ...
# 136985     547150  odersky 2011-12-01 12:39:40+00:00
# 136986     547150  odersky 2011-12-01 12:39:40+00:00
# 136987     547150  odersky 2011-12-01 12:39:40+00:00
# 136988     547003  robinst 2011-12-01 11:42:26+00:00
# 136989     547003  robinst 2011-12-01 11:42:26+00:00
#
#                                                      file  month  year
# 0                         test/files/pos/t5638/Among.java      1  2018
# 1                        test/files/pos/t5638/Usage.scala      1  2018
# 2                              test/files/pos/t9291.scala      1  2018
# ...

# %%
counts = mergedata.groupby(['year', 'month'])['pid'].count()

# %%
counts
# Out:
# year  month
# 2011  12       1180
# 2012  1         978
#       2        1574
#       3        1760
#       4        6708
#                ...
# 2017  9         578
#       10        535
#       11        172
#       12        224
# 2018  1         202
# Name: pid, Length: 74, dtype: int64

# %%
counts.plot(kind='bar', figsize=(18,4))
plt.show()
