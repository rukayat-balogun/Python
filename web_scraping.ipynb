# %%
pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq

# %%
trends = TrendReq()
trends

# %%
kw_list = ["Machine Learning"]
trends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)

# %%
data
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   44
# Singapore                  44
# St. Helena                 34
# India                      34
# Pakistan                   25
# Tunisia                    24
# Hong Kong                  23
# South Korea                21
# Nepal                      21

# %% [markdown]
# # Visualization

# %%
data.reset_index().plot(x="geoName", y="Machine Learning",figsize=(15,5), kind='bar')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=["Machine Learning"])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(18,15))
data["Machine Learning"].plot()
plt.style.use("fivethirtyeight")
plt.title("Google search result for Machine Learning for  4 years")
plt.savefig('google_search.png')
plt.show()

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
pytrends.trending_searches(pn="nigeria")
# Out:
#                             0
# 0                      Soludo
# 1                 Tobi Amusan
# 2                   Wike news
# 3           Warriors vs Spurs
# 4               Ashton United
# 5                     Ronaldo
# 6                  Hank Anuku
# 7                   Kuda Bank
# 8              Michael Boulos
# 9       INEC voters' register
# 10                     Monaco
# 11           Nnamdi Kanu news
# 12             Lakers vs Nets
# 13       Fulham vs Man United
# 14             PSG vs Auxerre
# 15          Atalanta vs Inter
# 16        Milan vs Fiorentina
# 17          Juventus vs Lazio
# 18  Davido and Chioma wedding
# 19                       Roma

# %%
pytrends.top_charts(2022-11, hl='en-US',tz=300, geo='us')

# %%
data
# Out:
#             Machine Learning  isPartial
# date
# 2017-11-19                56      False
# 2017-11-26                53      False
# 2017-12-03                54      False
# 2017-12-10                55      False
# 2017-12-17                53      False
# ...                      ...        ...
# 2022-10-09                92      False
# 2022-10-16                88      False
# 2022-10-23                84      False
# 2022-10-30                90      False
# 2022-11-06                94       True
#
# [260 rows x 2 columns]

# %%
data.head(20)
# Out:
#             Machine Learning  isPartial
# date
# 2017-11-19                56      False
# 2017-11-26                53      False
# 2017-12-03                54      False
# 2017-12-10                55      False
# 2017-12-17                53      False
# 2017-12-24                41      False
# 2017-12-31                53      False
# 2018-01-07                54      False
# 2018-01-14                52      False
# 2018-01-21                54      False
# 2018-01-28                57      False
# 2018-02-04                55      False
# 2018-02-11                55      False
# 2018-02-18                55      False
# 2018-02-25                58      False
# 2018-03-04                57      False
# 2018-03-11                58      False
# 2018-03-18                66      False
# 2018-03-25                56      False
# 2018-04-01                57      False

# %%
plt.savefig('google_search.png')
